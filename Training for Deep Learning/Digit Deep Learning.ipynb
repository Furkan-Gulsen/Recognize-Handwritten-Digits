# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('drive/My Drive/Developer Files/Python Repository/Image Processing & Computer Vision/Sudoku Solver')
# !pwd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-a9d418e10111> in <module>()
#       1 import os
# ----> 2 os.chdir('drive/My Drive/Developer Files/Python Repository/Image Processing & Computer Vision/Sudoku Solver')
#       3 get_ipython().system('pwd')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/My Drive/Developer Files/Python Repository/Image Processing & Computer Vision/Sudoku Solver'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

np.random.seed(2)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau


sns.set(style='white', context='notebook', palette='deep')

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 50

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('digit_model.h5')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.2630 - accuracy: 0.9203 - val_loss: 0.0595 - val_accuracy: 0.9806
# Epoch 2/50
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.0933 - accuracy: 0.9725 - val_loss: 0.0480 - val_accuracy: 0.9840
# Epoch 3/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0676 - accuracy: 0.9799 - val_loss: 0.0334 - val_accuracy: 0.9890
# Epoch 4/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0570 - accuracy: 0.9827 - val_loss: 0.0315 - val_accuracy: 0.9894
# Epoch 5/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0464 - accuracy: 0.9860 - val_loss: 0.0313 - val_accuracy: 0.9891
# Epoch 6/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0417 - accuracy: 0.9880 - val_loss: 0.0284 - val_accuracy: 0.9897
# Epoch 7/50
# 60000/60000 [==============================] - 9s 154us/step - loss: 0.0376 - accuracy: 0.9882 - val_loss: 0.0296 - val_accuracy: 0.9899
# Epoch 8/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0341 - accuracy: 0.9895 - val_loss: 0.0272 - val_accuracy: 0.9906
# Epoch 9/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0309 - accuracy: 0.9908 - val_loss: 0.0266 - val_accuracy: 0.9916
# Epoch 10/50
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.0297 - accuracy: 0.9906 - val_loss: 0.0244 - val_accuracy: 0.9920
# Epoch 11/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0275 - accuracy: 0.9915 - val_loss: 0.0263 - val_accuracy: 0.9898
# Epoch 12/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0264 - accuracy: 0.9920 - val_loss: 0.0284 - val_accuracy: 0.9910
# Epoch 13/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0255 - accuracy: 0.9922 - val_loss: 0.0278 - val_accuracy: 0.9923
# Epoch 14/50
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.0245 - accuracy: 0.9925 - val_loss: 0.0273 - val_accuracy: 0.9916
# Epoch 15/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0228 - accuracy: 0.9930 - val_loss: 0.0254 - val_accuracy: 0.9918
# Epoch 16/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0218 - accuracy: 0.9932 - val_loss: 0.0281 - val_accuracy: 0.9924
# Epoch 17/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0215 - accuracy: 0.9929 - val_loss: 0.0284 - val_accuracy: 0.9926
# Epoch 18/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.0293 - val_accuracy: 0.9919
# Epoch 19/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.0287 - val_accuracy: 0.9922
# Epoch 20/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.0261 - val_accuracy: 0.9916
# Epoch 21/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 0.0265 - val_accuracy: 0.9924
# Epoch 22/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.0291 - val_accuracy: 0.9917
# Epoch 23/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0190 - accuracy: 0.9943 - val_loss: 0.0302 - val_accuracy: 0.9914
# Epoch 24/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.0321 - val_accuracy: 0.9906
# Epoch 25/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0262 - val_accuracy: 0.9936
# Epoch 26/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0183 - accuracy: 0.9946 - val_loss: 0.0280 - val_accuracy: 0.9924
# Epoch 27/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 0.0302 - val_accuracy: 0.9927
# Epoch 28/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 0.0277 - val_accuracy: 0.9923
# Epoch 29/50
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.0290 - val_accuracy: 0.9920
# Epoch 30/50
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0299 - val_accuracy: 0.9919
# Epoch 31/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.0293 - val_accuracy: 0.9922
# Epoch 32/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.0285 - val_accuracy: 0.9925
# Epoch 33/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.0331 - val_accuracy: 0.9916
# Epoch 34/50
# 60000/60000 [==============================] - 9s 147us/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0332 - val_accuracy: 0.9926
# Epoch 35/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.0331 - val_accuracy: 0.9919
# Epoch 36/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.0287 - val_accuracy: 0.9926
# Epoch 37/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.0338 - val_accuracy: 0.9913
# Epoch 38/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.0374 - val_accuracy: 0.9925
# Epoch 39/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.0316 - val_accuracy: 0.9926
# Epoch 40/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.0352 - val_accuracy: 0.9921
# Epoch 41/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0321 - val_accuracy: 0.9924
# Epoch 42/50
# 60000/60000 [==============================] - 9s 150us/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.0422 - val_accuracy: 0.9909
# Epoch 43/50
# 60000/60000 [==============================] - 9s 151us/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.0323 - val_accuracy: 0.9920
# Epoch 44/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0271 - val_accuracy: 0.9922
# Epoch 45/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0362 - val_accuracy: 0.9921
# Epoch 46/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0329 - val_accuracy: 0.9925
# Epoch 47/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0361 - val_accuracy: 0.9927
# Epoch 48/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0403 - val_accuracy: 0.9927
# Epoch 49/50
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0325 - val_accuracy: 0.9927
# Epoch 50/50
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.0336 - val_accuracy: 0.9922
# Test loss: 0.03357278046673444
# Test accuracy: 0.9922000169754028

# %%
# !pip install tensorflowjs

# %%
# !tensorflowjs_converter --input_format keras "digit_model.h5" "./model"
